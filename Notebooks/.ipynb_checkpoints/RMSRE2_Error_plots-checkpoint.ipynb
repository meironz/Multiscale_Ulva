# %%
# Sensitivity analysis functions
import SALib
from SALib.sample import saltelli
from SALib.analyze import sobol
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
from __future__ import division
import numpy as np
from scipy.integrate import solve_ivp
from scipy import interpolate 
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from datetime import date
import datetime
from myfunctions_multi_scale import *
# %matplotlib inline

# %%
# importing parameters for validation with Reading data 

xval = pd.ExcelFile('../data/input.xlsx')
dfval = xval.parse('Parameters_Reading',header=None)

# assigmment of parameters to values: 
for key,val in zip(dfval.iloc[:][0],dfval.iloc[:][1]):
    exec(key + '=val')
    print(key,val)

n_reactors = np.int(n_reactors)
# Out:
# umol_to_percent_DW 0.0014
# n_days 14.0
# Next0 110.0
# Nint0 1.05
# m0 0.19724999999999998
# S 35.0
# Nintcrit 2.0
# n_reactors 1.0
# Qp 459.5833333333333
# Qsea 224910.0
# Nsea 110.0
# dilution 0.0
# miu 0.027
# Nintmax 4.2
# Nintmin 0.7
# KN 1.2
# Ks 14.0
# Vmax 60.0
# Z 1.0
# KI 20.0
# K0 1.5
# Ka 0.15
# Topt 18.0
# Tmin 5.0
# Tmax 31.5
# n 2.0
# losses20 0.0016
# teta 1.047
# Sopt 18.0
# Smin 0.0
# Smax 45.0
# Shigh 30.0
# Slow 12.0

# %%
problem = {
    'num_vars': 6,
    'names': ['miu','KI', 'n','Tmax','Topt','losses20'],
    'bounds': [[0.025,0.035],
               [15, 150],
               [1, 6],
               [29, 32],
               [15, 20],
               [0.001,0.005]]
}
print(problem)
# Out:
# {'num_vars': 6, 'names': ['miu', 'KI', 'n', 'Tmax', 'Topt', 'losses20'], 'bounds': [[0.025, 0.035], [15, 150], [1, 6], [29, 32], [15, 20], [0.001, 0.005]]}

# %%
param_values = saltelli.sample(problem, 20)
print(param_values.shape)
# Out:
# (280, 6)

# %%
# import all data for model valodation (source: HOBO data from aerated cage in Reading - Alex Ch, 2017)

period1i = datetime.datetime(2017, 4, 20)
hour1i = 24 * (int(period1i.strftime("%j"))-1) + 8

period2i = datetime.datetime(2017, 5, 3)
hour2i = 24 * (int(period2i.strftime("%j"))-1) + 14

period3i = datetime.datetime(2017, 5, 17)
hour3i = 24 * (int(period3i.strftime("%j"))-1) + 14

period4i = datetime.datetime(2017, 6, 15)
hour4i = 24 * (int(period4i.strftime("%j"))-1) + 12

period5i = datetime.datetime(2017, 6, 28)
hour5i = 24 * (int(period5i.strftime("%j"))-1) + 11

x2 = pd.ExcelFile('../data/HOBO.xlsx')

dfV1 = x2.parse('period1_PAR',header=None)
dfV4 = x2.parse('period2_PAR',header=None)
dfV5 = x2.parse('period3_PAR',header=None)

#IV1 and TV1 based only on IMS and not on HOBO data

IV2, TV2,IV2_average,TV2_average = [],[],[],[]
for vali,valT in zip(dfV1.iloc[3:2488:1][5],dfV1.iloc[3:2488:1][3]):
    IV2.append(vali)
    TV2.append(float(valT))
for i in range(1,len(IV2),4):
    IV2_average.append(np.mean(IV2[i-1:i+3:1]))
    TV2_average.append(np.mean(TV2[i-1:i+3:1]))

IV3, TV3,IV3_average,TV3_average = [],[],[],[]
for vali,valT in zip(dfV1.iloc[3+14*24*4:2488:1][5],dfV1.iloc[3+14*24*4:2488:1][3]):
    IV3.append(vali)
    TV3.append(float(valT))
for i in range(1,len(IV3),4):
    IV3_average.append(np.mean(IV3[i-1:i+3:1]))
    TV3_average.append(np.mean(TV3[i-1:i+3:1]))
    
IV4, TV4,IV4_average,TV4_average = [],[],[],[]
for vali,valT in zip(dfV4.iloc[13:1249:1][5],dfV4.iloc[13:1249:1][3]):
    IV4.append(vali)
    TV4.append(float(valT))
for i in range(1,len(IV4),4):
    IV4_average.append(np.mean(IV4[i-1:i+3:1]))
    TV4_average.append(np.mean(TV4[i-1:i+3:1]))

IV5, TV5,IV5_average,TV5_average = [],[],[],[]
for vali,valT in zip(dfV5.iloc[7:1345:1][5],dfV5.iloc[7:1345:1][3]):
    IV5.append(vali)
    TV5.append(float(valT))
for i in range(1,len(IV5),4):
    IV5_average.append(np.mean(IV5[i-1:i+3:1]))
    TV5_average.append(np.mean(TV5[i-1:i+3:1]))

# %%
# Import of IMS I and T data
dFI = pd.read_csv('../data/ims_data_2017_PAR.csv',encoding= 'unicode_escape',header=None)
dfT = pd.read_csv('../data/ims_T_data_2017.csv',encoding= 'unicode_escape',header=None)

# %%
# process IMS I and T Data

# I data
days = list(range(1,366))
I = np.zeros(24*365)
Temp = np.zeros(24*365-1-24)
light_hours = list(range(5,19))
for day in days:
    for hour in light_hours:
        I[(day - 1)*24 + hour] = float(dFI.iloc[day][hour-1])

# T data
annual_hours_short = list(range(2,2741*3-1))
annual_hours = list(range(1,(366-1)*24+1))
f0 = interpolate.interp1d(annual_hours, I,kind = 'linear')

TV1 = []
for valT in zip(dfT.iloc[1:2741:1][4]):
    TV1.append(float(valT[0]))
TV1[-1]

TV_hours_reduced = annual_hours_short[0:-1:3]
f2 = interpolate.interp1d(TV_hours_reduced,TV1,kind = 'linear')
TV_interp = f2(annual_hours_short[0:-5:1])

# %%
# Lists of initial and boundary conditions and empiric results for returns 1-5:

t0_all = [hour1i, hour2i, hour3i, hour4i, hour5i]
tf_all = [hour1i + int(13*24), hour2i + int(14*24), hour3i + int(12*24-4), hour4i + int(13*24-4), hour5i + int(14*24-2)]
Nsea_all = [90, 111, 91, 148, 206] # in period 3 used final concentrations
mi_all = [1.315*0.15, 1.315*0.15, 1.315*0.15, 1.306*0.15, 1.306*0.15]
mf_real = [4590, 2781, 1120, 2001, 1069]
Nint0_all = [2, 1.05, 0.65, 3, 1.06]# Nint0 of first period - assumed 2 (after 1 week starvation), and of forth assumed 3 (after fertilizing in Porter)
Nintf_all = [1.05, 0.65, 0.98, 1.06, 1.40]
functions = [Reading_val, Reading_val_IMS]
TV_average = [TV1, TV2_average, TV3_average, TV4_average, TV5_average]
IV_average = [1, IV2_average, IV3_average, IV4_average, IV5_average]
xlabels_all = [['20 April', '27 April', '3 May'],['3 May', '10 May', '17 May'],['17 May', '23 May', '29 May'],['15 June', '22 june', '28 June'],['28 June', '5 July', '12 July']]

# %%
Y = np.zeros([param_values.shape[0]])
evaluate_model = []
for i, X in enumerate(param_values):
    miu = X[0]
    KI = X[1]
    n = X[2]
    Tmax = X[3]
    Topt = X[4]
    losses20  = X[5]
    
    returns = [1, 2, 4, 5]
    Errors = []
    for k in returns:
        t0 = t0_all[k-1]
        t = list(range(t0,tf_all[k-1]))
        Nsea = Nsea_all[k-1]
        Next0 = Nsea_all[k-1]
        Nint0 = Nint0_all[k-1]
        m0 = mi_all[k-1]
        TV_reduced = TV_average[k-1][1:len(t)+1]
        f1 = interpolate.interp1d(t, TV_reduced,kind = 'linear')    
        f0 = interpolate.interp1d(annual_hours, I,kind = 'linear')

        NSEA, NEXT, NINT, M, Total_N, T, Total_biomass, FINAL_M = [],[],[],[],[],[],[],[]

        # setup initial conditions identical for all reactors
        x0 = n_reactors*[Nsea, Next0, Nint0, m0]
        args = (Nintcrit,Nintmax,Nintmin,Vmax,Ks,KN,miu,S,Z,KI,K0,Ka,Topt,Tmin,Tmax,losses20,
                teta,Sopt,Smin,Smax, Qp, Qsea, Nsea,f1,f0,dilution,n,umol_to_percent_DW)

        # solve the ODEs using the new syntax
        sol = solve_ivp(Reading_val_IMS, [t[0], t[-1]], x0, args=args, t_eval = t)

        # take the solution of the state variables:
        M_farm, N_farm = [], []
        NSEA.append(sol.y[0,:])
        NEXT.append(sol.y[1,:])
        NINT.append(sol.y[2,:])
        M.append(sol.y[3,:])
        M_farm.append((M[-1][-1] - m0) * 1.785)
        N_farm.append((M[-1][-1] * NINT[-1][-1] * 1.785 / 100))
        Total_biomass.append(round(sum(M_farm),3))
        Total_N.append(round(sum(N_farm),4))

        T.append(sol.t)
        t = T[0]

        final_m = round(M [-1][-1] * 1.785 / 0.15,4)
        measured_m = round(mf_real[k-1] * 1.785 / 1000,4)
        FINAL_M.append(final_m)
        error = abs(round((measured_m - final_m) / measured_m,4))
        square_error = error**2
        Errors.append(square_error)
        
    evaluate_model.append((np.mean(Errors))**0.5)
    Y[i] = evaluate_model[-1]
print(Y)
# Out:
# [0.49390186 0.5169331  0.70335588 0.49787265 0.57224818 0.50281721
#  0.17884391 0.51314023 0.30343405 0.52080504 0.48789757 0.51927877
#  0.73855419 0.52202876 0.58284165 0.58941036 0.55452635 0.58811228
#  0.56803346 0.58201589 0.69860783 0.66842047 0.69724055 0.66983483
#  0.68739818 0.67590159 0.55312585 0.67567293 0.16284077 0.19042081
#  0.40596307 0.23232347 0.16075923 0.18926434 0.27425155 0.29938434
#  0.48031695 0.2491076  0.36685884 0.39341088 0.20184201 0.38065523
#  0.653387   0.64019632 0.63244054 0.61269953 0.65768947 0.65043892
#  0.38938555 0.28250146 0.30114738 0.3336086  0.24201288 0.26111123
#  0.56446652 0.25323406 0.67758361 0.67411968 0.5393639  0.64418837
#  0.66232015 0.67074755 0.420951   0.41300407 0.29907069 0.20376272
#  0.37697464 0.23560077 0.37635813 0.44306375 0.41443288 0.4086791
#  0.293899   0.39164879 0.46864062 0.42040711 0.56332389 0.52343553
#  0.59657525 0.53730111 0.43530409 0.51270742 0.35691503 0.51809478
#  0.21570914 0.24385135 0.36704687 0.23186598 0.18949479 0.20190227
#  0.59232465 0.67049826 0.57522873 0.70880785 0.71133935 0.67923067
#  0.35527648 0.69173104 0.54629477 0.50214809 0.41433633 0.62923542
#  0.51184922 0.53918588 0.48148712 0.46234846 0.52315135 0.18721791
#  0.4388787  0.41305833 0.47762439 0.40474291 0.44363725 0.36184949
#  0.5492472  0.45299691 0.44634311 0.44308976 0.43043987 0.54347705
#  0.36450666 0.50350389 0.50770427 0.50947382 0.52077426 0.50934467
#  0.59297081 0.60079779 0.47739702 0.59530898 0.59629438 0.58970174
#  0.58339592 0.46985435 0.59359994 0.47886862 0.4770238  0.48746877
#  0.49404123 0.48252058 0.52041431 0.52768904 0.34790687 0.45527423
#  0.47900735 0.5179357  0.68188949 0.39213947 0.58627122 0.48346901
#  0.47873051 0.39585189 0.36403752 0.39318514 0.31118736 0.3205657
#  0.22400188 0.37842921 0.3490461  0.30882988 0.52230245 0.55736971
#  0.60771802 0.50889457 0.5254274  0.5669762  0.34869595 0.56402688
#  0.31449029 0.29998649 0.25893516 0.28725373 0.2785294  0.33605615
#  0.30056654 0.19213996 0.23705311 0.19731882 0.22899538 0.22631449
#  0.19880968 0.19354676 0.71864625 0.74391736 0.70709032 0.69318036
#  0.71087515 0.71596148 0.7116052  0.64895559 0.70443605 0.71930146
#  0.70175024 0.6977606  0.69904506 0.69161487 0.30693712 0.33757319
#  0.55115258 0.39696637 0.42066568 0.33206638 0.31076002 0.65855818
#  0.45853994 0.59179583 0.62185421 0.65511635 0.66302305 0.65433834
#  0.37637236 0.36439084 0.33820954 0.344632   0.35847766 0.39226219
#  0.36271131 0.28205001 0.31385185 0.30677298 0.29049755 0.24834331
#  0.28037395 0.26558534 0.28578378 0.24954951 0.23302943 0.28681494
#  0.25788944 0.28595878 0.34018268 0.25493507 0.27374285 0.22452734
#  0.25797034 0.22474173 0.18544366 0.22466403 0.57840876 0.61209285
#  0.55895085 0.58040056 0.56396569 0.57859386 0.61335311 0.5823202
#  0.63631937 0.61910038 0.6326633  0.6208213  0.58634949 0.62098718
#  0.43618224 0.44157553 0.65515987 0.52538555 0.28068746 0.43627862
#  0.46537484 0.69777234 0.48991139 0.63961856 0.72965693 0.70200657
#  0.6752451  0.7021509  0.482475   0.49018617 0.45309221 0.39905509
#  0.4998702  0.48266704 0.52503297 0.44178437 0.48564668 0.52499062
#  0.41832564 0.45195641 0.40413402 0.45221042]

# %%
print(min(Y))
print(np.mean(Y))
print(np.std(Y))
print(np.median(Y))
print(max(Y))
# Out:
# 0.16075922990609282
# 0.4658829450867318
# 0.1555681902465893
# 0.48090203802344417
# 0.7439173576412906

# %%
fig,ax = plt.subplots(1,1,sharex=True,figsize=(4,5))
ax.set_xlabel('Error',fontsize=14, weight="bold")
ax.set_ylabel('Frequency',fontsize=14, weight="bold")
ax.hist(Y,bins=21)
# Out:
# (array([ 5., 11., 13., 10., 15., 12., 10., 15., 13., 12., 15., 20., 20.,
#         15., 13., 20., 11., 12., 14., 19.,  5.]),
#  array([0.16075923, 0.18852866, 0.2162981 , 0.24406753, 0.27183697,
#         0.2996064 , 0.32737584, 0.35514527, 0.38291471, 0.41068414,
#         0.43845358, 0.46622301, 0.49399245, 0.52176188, 0.54953132,
#         0.57730075, 0.60507018, 0.63283962, 0.66060905, 0.68837849,
#         0.71614792, 0.74391736]),
#  <a list of 21 Patch objects>)

# %%
# Density Plot and Histogram of all arrival delays

sns.distplot(Y, hist=True, kde=True,
             bins=105, color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
Si = sobol.analyze(problem, Y,print_to_console=True)
# Out:
# Parameter S1 S1_conf ST ST_conf
# miu 0.085379 0.049102 0.015952 0.017724
# KI 0.332948 0.313427 0.363153 0.222845
# n 0.124864 0.114206 0.050532 0.033181
# Tmax 0.015055 0.199479 0.055714 0.049683
# Topt -0.017452 0.032078 0.002537 0.001853
# losses20 0.343271 0.479914 0.516742 0.396736
#
# Parameter_1 Parameter_2 S2 S2_conf
# miu KI -0.117294 0.102569
# miu n -0.068870 0.129859
# miu Tmax -0.069037 0.145314
# miu Topt -0.071782 0.138975
# miu losses20 -0.109310 0.119256
# KI n -0.361957 0.341449
# KI Tmax -0.307572 0.360901
# KI Topt -0.287570 0.292612
# KI losses20 -0.071797 0.467653
# n Tmax -0.086550 0.271351
# n Topt -0.108878 0.274664
# n losses20 0.000120 0.203611
# Tmax Topt -0.027986 0.210888
# Tmax losses20 0.034416 0.227229
# Topt losses20 0.025938 0.051650

# %%
a = param_values.T

# %%
fig,axmiu = plt.subplots(1,1,sharex=True,figsize=(4,5))
axmiu.plot(a[0],Y,'.',markersize=5)
axmiu.set_xlabel('miu',fontsize=14, weight="bold")
axmiu.set_ylabel('Error',fontsize=14, weight="bold")
axmiu.set_xlim([0.025, 0.035])
# Out:
# (0.025, 0.035)

# %%
# fit with np.polyfit
x = a[0]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 8.067783564058573e-05

# %%
fig,axKI = plt.subplots(1,1,sharex=True,figsize=(4,5))
axKI.plot(a[1],Y,'.',markersize=5)
axKI.set_xlabel('KI',fontsize=14, weight="bold")
axKI.set_ylabel('Error',fontsize=14, weight="bold")
axKI.set_xlim([15, 150])
# Out:
# (15, 150)

# %%
# fit with np.polyfit
x = a[1]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.2984155977343873

# %%
fig,axn = plt.subplots(1,1,sharex=True,figsize=(4,5))
axn.plot(a[2],Y,'.',markersize=5)
axn.set_xlabel('n',fontsize=14, weight="bold")
axn.set_ylabel('Error',fontsize=14, weight="bold")
axn.set_xlim([1, 6])
# Out:
# (1, 6)

# %%
# fit with np.polyfit
x = a[2]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.23980517597166606

# %%
fig,axTmax = plt.subplots(1,1,sharex=True,figsize=(4,5))
axTmax.plot(a[3],Y,'.',markersize=5)
axTmax.set_xlabel('Tmax',fontsize=14, weight="bold")
axTmax.set_ylabel('Error',fontsize=14, weight="bold")
axTmax.set_xlim([29, 32])# fit with np.polyfit
x = a[3]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

# %%
# fit with np.polyfit
x = a[3]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.023348233931267504

# %%
fig,axTopt = plt.subplots(1,1,sharex=True,figsize=(4,5))
axTopt.plot(a[4],Y,'.',markersize=5)
axTopt.set_xlabel('Topt',fontsize=14, weight="bold")
axTopt.set_ylabel('Error',fontsize=14, weight="bold")
axTopt.set_xlim([15, 20])
# Out:
# (15, 20)

# %%
# fit with np.polyfit
x = a[4]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.0015160011564047116

# %%
fig,axTopt = plt.subplots(1,1,sharex=True,figsize=(4,5))
axTopt.plot(a[5],Y,'.',markersize=5)
axTopt.set_xlabel('losses20',fontsize=14, weight="bold")
axTopt.set_ylabel('Error',fontsize=14, weight="bold")
axTopt.set_xlim([0.001, 0.005])
# Out:
# (0.001, 0.005)

# %%
# fit with np.polyfit
x = a[5]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.5368036272741166

# %%
import statsmodels.formula.api as smf

#import numpy as np
x = a[3].T
y
degree = 10
weights = np.polyfit(x, y, degree)

model = np.poly1d(weights)
df = pd.DataFrame(columns=['y', 'x'])
df['x'] = x
df['y'] = y

results = smf.ols(formula='y ~ model(x)', data=df).fit()
results.summary()
# Out:
# C:\Users\meiro\Anaconda3new\lib\site-packages\IPython\core\interactiveshell.py:3331: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.159
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     52.59
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):           4.08e-12
# Time:                        23:54:51   Log-Likelihood:                 147.94
# No. Observations:                 280   AIC:                            -291.9
# Df Residuals:                     278   BIC:                            -284.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9.169e-07      0.065   1.41e-05      1.000      -0.128       0.128
# model(x)       1.0000      0.138      7.252      0.000       0.729       1.271
# ==============================================================================
# Omnibus:                       21.767   Durbin-Watson:                   0.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.545
# Skew:                          -0.220   Prob(JB):                      0.00846
# Kurtosis:                       2.210   Cond. No.                         19.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
Best_index = []
for i in range(len(Y)):
    if Y[i] < 1:
        #print("parameters of index " + str(i) + " give error " + str(Y[i]) + "\n")
        Best_index.append(i)
        
b = param_values[Best_index].T

print(b)
fig,ax0 = plt.subplots(2,3,figsize=(14,10),sharey=True)#,sharex=True)

ax0.flat[0].plot(b[0],Y[Best_index],'.',markersize=4)
ax0.flat[0].set_xlabel('µmax\n [$hour^{-1}$]',fontsize=11, weight="bold")
ax0.flat[0].set_ylabel('RMSRE',fontsize=12, weight="bold")
ax0.flat[0].set_xlim([0.025, 0.035])

ax0.flat[1].plot(b[5],Y[Best_index],'.',markersize=4)
ax0.flat[1].set_xlabel('λ\N{SUBSCRIPT TWO}\N{SUBSCRIPT ZERO}\n [$hour^{-1}$]',fontsize=11, weight="bold")
# regression line:
mm, bb = np.polyfit(b[5], Y[Best_index], 1)
ax0.flat[1].plot(b[5], mm*b[5] + bb,'.',color = 'darkblue',markersize=4)


x = np.array(b[5]).reshape((-1, 1))
model = LinearRegression()
model.fit(x, Y[Best_index])
model = LinearRegression().fit(x, Y[Best_index])

r_sq = model.score(x, Y[Best_index])
print('λ\N{SUBSCRIPT TWO}\N{SUBSCRIPT ZERO} coefficient of determination:', r_sq)
ax0.flat[1].legend(['$R^{2}$ = ' + str(round(r_sq,2))])


#fig,ax0 = plt.subplots(1,1,sharex=True,figsize=(4,5))
ax0.flat[2].plot(b[1],Y[Best_index],'.',markersize=4)
ax0.flat[2].set_xlabel('KI \n [µmol photons $s^{-1}$ $m^{-2}$]',fontsize=11, weight="bold")
# regression line:
mm, bb = np.polyfit(b[1], Y[Best_index], 1)
ax0.flat[2].plot(b[1], mm*b[1] + bb, '.',color = 'darkblue',markersize=4)


x = np.array(b[2]).reshape((-1, 1))
model = LinearRegression()
model.fit(x, Y[Best_index])
model = LinearRegression().fit(x, Y[Best_index])

r_sq = model.score(x, Y[Best_index])
print('KI coefficient of determination:', r_sq)
ax0.flat[2].legend(['$R^{2}$ = ' + str(round(r_sq,2))])

ax0.flat[3].plot(b[2],Y[Best_index],'.',markersize=4)
ax0.flat[3].set_xlabel('n\n [-]',fontsize=11, weight="bold")
ax0.flat[3].set_ylabel('RMSRE',fontsize=12, weight="bold")

ax0.flat[4].plot(b[3],Y[Best_index],'.',markersize=4)
ax0.flat[4].set_xlabel('Tmax\n [C]',fontsize=11, weight="bold")

ax0.flat[5].plot(b[4],Y[Best_index],'.',markersize=4)
ax0.flat[5].set_xlabel('Topt\n [C]',fontsize=11, weight="bold")

#plt.tight_layout()

plt.show()

name = 'fig_S8.png' 
fig.savefig(fname=name, dpi=600)
# Out:
# [[2.71972656e-02 2.54589844e-02 2.71972656e-02 ... 2.76464844e-02
#   2.76464844e-02 2.76464844e-02]
#  [2.80517578e+01 2.80517578e+01 1.36420898e+02 ... 8.15771484e+01
#   8.15771484e+01 8.15771484e+01]
#  [3.59277344e+00 3.59277344e+00 3.59277344e+00 ... 4.59863281e+00
#   4.59863281e+00 4.59863281e+00]
#  [3.10302734e+01 3.10302734e+01 3.10302734e+01 ... 3.04267578e+01
#   3.04267578e+01 3.04267578e+01]
#  [1.64013672e+01 1.64013672e+01 1.64013672e+01 ... 1.65576172e+01
#   1.65185547e+01 1.65185547e+01]
#  [4.62890625e-03 4.62890625e-03 4.62890625e-03 ... 2.64453125e-03
#   2.25390625e-03 2.64453125e-03]]
# λ₂₀ coefficient of determination: 0.5368036272741166
# KI coefficient of determination: 0.23980517597166606

# %%
# Calculating root mean square error

# model simulation

Ka = 0.15
KI = 20
n = 2
Tmax = 31.5
Topt = 18
losses20 = 0.0016


returns = [1, 2, 4, 5]
Errors = []
Square_errors = []
for k in returns:
    t0 = t0_all[k-1]
    t = list(range(t0,tf_all[k-1]))
    Nsea = Nsea_all[k-1]
    Next0 = Nsea_all[k-1]
    Nint0 = Nint0_all[k-1]
    m0 = mi_all[k-1]
    TV_reduced = TV_average[k-1][1:len(t)+1]
    f1 = interpolate.interp1d(t, TV_reduced,kind = 'linear')    
    f0 = interpolate.interp1d(annual_hours, I,kind = 'linear')

    NSEA, NEXT, NINT, M, Total_N, T, Total_biomass, FINAL_M = [],[],[],[],[],[],[],[]

    # setup initial conditions identical for all reactors
    x0 = int(n_reactors)*[Nsea, Next0, Nint0, m0]
    args = (Nintcrit,Nintmax,Nintmin,Vmax,Ks,KN,miu,S,Z,KI,K0,Ka,Topt,Tmin,Tmax,losses20,
            teta,Sopt,Smin,Smax, Qp, Qsea, Nsea,f1,f0,dilution,n,umol_to_percent_DW)

    # solve the ODEs using the new syntax
    sol = solve_ivp(Reading_val_IMS, [t[0], t[-1]], x0, args=args, t_eval = t)

    # take the solution of the state variables:
    M_farm, N_farm = [], []
    NSEA.append(sol.y[0,:])
    NEXT.append(sol.y[1,:])
    NINT.append(sol.y[2,:])
    M.append(sol.y[3,:])
    M_farm.append((M[-1][-1] - m0) * 1.785)
    N_farm.append((M[-1][-1] * NINT[-1][-1] * 1.785 / 100))
    Total_biomass.append(round(sum(M_farm),3))
    Total_N.append(round(sum(N_farm),4))

    T.append(sol.t)
    t = T[0]

    final_m = round(M [-1][-1] * 1.785 / 0.15,4)
    measured_m = round(mf_real[k-1] * 1.785 / 1000,4)
    FINAL_M.append(final_m)
    error = abs(round((measured_m - final_m) / measured_m,4))
    square_error = error**2
    Errors.append(error)
    Square_errors.append(square_error)

    print('for return ' + str(k) + ' and using IMS irradiance data')
    print('The modeled m is: ' + str(final_m) + '[kg FW/cage] and the measured m is ' + str(measured_m) + '[kg FW/cage] \n')
    print('The calculated error is: ' + str(error) + '\n')

print('the mean error is: ' + str(np.mean(Errors)) + '\n')
print('the std  is: ' + str(np.std(Errors)) + '\n')
print('the RMSE is: ' + str((np.mean(Square_errors))**0.5) + '\n')
# Out:
# for return 1 and using IMS irradiance data
# The modeled m is: 7.2352[kg FW/cage] and the measured m is 8.1931[kg FW/cage]
#
# The calculated error is: 0.1169
#
# for return 2 and using IMS irradiance data
# The modeled m is: 5.731[kg FW/cage] and the measured m is 4.9641[kg FW/cage]
#
# The calculated error is: 0.1545
#
# for return 4 and using IMS irradiance data
# The modeled m is: 2.8954[kg FW/cage] and the measured m is 3.5718[kg FW/cage]
#
# The calculated error is: 0.1894
#
# for return 5 and using IMS irradiance data
# The modeled m is: 1.8825[kg FW/cage] and the measured m is 1.9082[kg FW/cage]
#
# The calculated error is: 0.0135
#
# the mean error is: 0.118575
#
# the std  is: 0.06586035890427565
#
# the RMSE is: 0.13563781736669167

# %%
fig,axlosses20 = plt.subplots(1,1,sharex=True,figsize=(4,5))
axlosses20.plot(a[5],Y,'.',markersize=5)
axlosses20.set_xlabel('losses20',fontsize=14, weight="bold")
axlosses20.set_ylabel('Error',fontsize=14, weight="bold")
axlosses20.set_xlim([0.001, 0.005])
# Out:
# (0.001, 0.005)

# %%
# fit with np.polyfit
x = a[4]
y = Y
m, b = np.polyfit(x, y, 1)

plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

x = np.array(x).reshape((-1, 1))
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)

r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.0015160011564047116
